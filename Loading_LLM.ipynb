# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install accelerate
# !pip install transformers
# !pip install bitsandbytes

# %%
# from huggingface_hub import notebook_login
from huggingface_hub import login

login(token="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")
import torch
import transformers
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM, BitsAndBytesConfig
from torch import cuda, bfloat16
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Smallest Llama2 model

# %%
model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model) # specify the tokenizer
pipeline = transformers.pipeline(   # to specify our task, our model, and our PyTorch datatype
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
sequences = pipeline(
    'Outline the steps to load a large language model using Python.\n',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    # max_length=200,
    max_new_tokens = 1000
)

# %%
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: Outline the steps to load a large language model using Python.
#
# To load a large language model using Python, you can follow these steps:
#
# Step 1: Install the necessary packages
# ---------------------------------------
#
# You will need to install the `transformers` package, which provides a convenient API for loading and using large language models. You can install it using pip:
# ```
# pip install transformers
# ```
# Step 2: Choose a model
# -------------------------
#
# There are many pre-trained large language models available, such as BERT, RoBERTa, and XLNet. You can choose the model you want to use based on its performance on your task and the size of the model.
#
# Step 3: Load the model
# -----------------------
#
# Once you have chosen a model, you can load it using the `from_pretrained` method of the `transformers` package:
# ```
# model = TransformerModel.from_pretrained('bert-base-uncased')
# ```
# This will load the BERT base uncased model, which is a popular and widely-used model.
#
# Step 4: Prepare the model for use
# ----------------------------------
#
# After loading the model, you may need to prepare it for use in your application. This can involve tokenizing the input data, padding the input sequences, and setting the model's hyperparameters.
#
# Step 5: Use the model
# -----------------------
#
# Once the model is prepared, you can use it to make predictions or generate text. For example:
# ```
# input_text = 'This is a sample input text.'
# output = model(input_text)
# print(output)
# ```
# This will generate the output text based on the input text and the model's predictions.
#
# Step 6: Save the model
# ---------------------
#
# After using the model, you may want to save it for later use. You can do this using the `save_pretrained` method of the `transformers` package:
# ```
# model.save_pretrained('bert-base-uncased.h5')
# ```
# This will save the model to a file with the name `bert-base-uncased.h5`.
#
# Conclusion
# ----------
#
# In this tutorial, we have outlined the steps to load a large language model using Python. By following these steps, you can easily use pre-trained models to improve the performance of your natural language processing tasks.

# %% [markdown]
# #  Llama2 2.7 Billion Parameter

# %%
# !pip install git+https://github.com/huggingface/transformers

# %%
from transformers import BitsAndBytesConfig
import torch
import transformers
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM, BitsAndBytesConfig

# %%
model_id = "meta-llama/Llama-2-7b-hf"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model_4bit = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
text = """
You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe.  Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.

If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information.


Question: What are the steps to load a large language model using Python? \n

Answer: """

device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model_4bit.generate(**inputs, max_new_tokens=1000)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe.  Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.
#
# If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information.
#
#
# Question: What are the steps to load a large language model using Python?
#
#
# Answer:
# The steps to load a large language model using Python are:
#
# - Install the necessary packages: pip install torch torchvision
#
# - Download the model: torch.hub.load_state_dict_from_url('https://huggingface.co/sparc/gpt-j-large-cased-squad2-mrcnn-mismatched/checkpoints/gpt-j-large-cased-squad2-mrcnn-mismatched-5e228418.pth.tar')
#
# - Load the model: from transformers import GPT2Tokenizer, GPT2Model
#
# - Create the model: model = GPT2Model.from_pretrained('gpt-j-large-cased-squad2-mrcnn-mismatched')
#
# - Train the model: model.train()
#
# - Evaluate the model: model.eval()
#
# - Predict the next word: model.predict(input_ids)

# %% [markdown]
# #Llama-2-13b-hf

# %%
model_id = "meta-llama/Llama-2-13b-hf"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model_4bit
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
text = """
You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe.  Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.

If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information.

Q: What are the steps to load a large language model using Python? Please explain the answer to me in terms that a 5th grader can understand. Thank you. \n

A: """

device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model_4bit.generate(**inputs, max_new_tokens=1000)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe.  Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.
#
# If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information.
#
# Q: What are the steps to load a large language model using Python? Please explain the answer to me in terms that a 5th grader can understand. Thank you.
#
#
# A:
#
# First, you need to download the large language model file. You can do this by visiting the website of the company that created the model.
#
# Second, you need to install the appropriate Python libraries. This will allow you to interact with the model.
#
# Third, you need to create a new file in your directory. This file will contain the code that will load the model.
#
# Fourth, you need to import the necessary libraries into the file. This will allow you to use the model.
#
# Fifth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Sixth, you need to import the model into the file. This will allow you to use the model.
#
# Seventh, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Eighth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Ninth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Tenth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Eleventh, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Twelfth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Thirteenth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Fourteenth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Fifteenth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Sixteenth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Seventeenth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Eighteenth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Nineteenth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Twentieth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Twenty-first, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Twenty-second, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Twenty-third, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Twenty-fourth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Twenty-fifth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Twenty-sixth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Twenty-seventh, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Twenty-eighth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Twenty-ninth, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Thirtieth, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Thirty-first, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Thirty-second, you need to create a new variable that will hold the model. This will allow you to access the model from within the file.
#
# Thirty-third, you need to load the model into memory. This will allow you to access the model from within the file.
#
# Thirty-fourth
